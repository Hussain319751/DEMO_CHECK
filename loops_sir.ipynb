# %%
import random
for i in range(3):
    num=random.randint(100,200)
    print(num*num)
# Out:
# 10000
# 40000
# 15376

# %%
# import random

check=False
for i in range(3):
    val1=random.randint(1,10)
    val2=eval(input('enter num'))
    if val1==val2:
        print('won')
        break
        check=True
    else:
        print('you lost in this attempt and remaining chances are',(3-i-1))
if not check:      
     print('try after')
# Out:
# enter num 1
# you lost in this attempt and remaining chances are 2
# enter num 1
# won
# enter num 1
# you lost in this attempt and remaining chances are 0
